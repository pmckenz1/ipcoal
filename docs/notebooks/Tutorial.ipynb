# %% [markdown]
# # Quickstart Tutorial

# %% [markdown]
# ##  Tutorial

# %%
import ipcoal
import toytree

# %% [markdown]
# #### 1) Provide a species tree

# %%
# init a model Class object for simulations
tree = toytree.rtree.unittree(8, treeheight=1e6)

# %%
# draw tree showing idx labels
tree.draw(tree_style='c');
# Out:
# <div class="toyplot" id="t649aeda31ad149bd93a916d8e875a972" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="250.0px" id="t52dbebe00f384c4d8ffbf635aff1163d" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 250.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t42f9396c631a4d5abf3625b982632817"><clipPath id="tb07029761bbd4cb3abe215d756a278af"><rect height="190.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#tb07029761bbd4cb3abe215d756a278af)"><g class="toyplot-mark-Graph" id="ta808112b67624b99a829dfb2a8520975"><g class="toyplot-Edges"><path d="M 273.2142857142857 80.0 L 300.0 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 246.42857142857144 110.0 L 264.2857142857143 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 246.42857142857144 110.0 L 228.57142857142856 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 273.2142857142857 80.0 L 246.42857142857144 110.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 216.29464285714283 50.0 L 273.2142857142857 80.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 159.375 80.0 L 192.85714285714283 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 125.89285714285714 110.0 L 157.1428571428571 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 94.64285714285714 140.0 L 121.42857142857142 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 67.85714285714286 170.0 L 85.71428571428572 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 67.85714285714286 170.0 L 50.0 200.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 94.64285714285714 140.0 L 67.85714285714286 170.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 125.89285714285714 110.0 L 94.64285714285714 140.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 159.375 80.0 L 125.89285714285714 110.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><path d="M 216.29464285714283 50.0 L 159.375 80.0" style="fill:none;opacity:1;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2.0"></path><g class="toyplot-HeadMarkers"></g><g class="toyplot-MiddleMarkers"></g><g class="toyplot-TailMarkers"></g></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.0, 200.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(8 ...
# name: r4
# dist: 200000
# support: 100
# height: 0</title><circle r="7.5"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.5020000000000002" y="2.2995">0</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1" transform="translate(85.71428571428572, 200.0)"><title>idx: 1
# name: r2
# dist: 200000
# support: 100
# height: 0</title><circle r="7.5"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.5020000000000002" y="2.2995">1</tex

# %% [markdown]
# #### 2) Create a model object

# %%
model = ipcoal.Model(tree=tree, Ne=1e6)

# %% [markdown]
# #### 3a) Simulate unlinked snps

# %%
# simulate N unlinked SNPs (will run until N snps are produced)
model.sim_snps(1000)

# %%
model.df
# Out:
#      locus  start  end  nbps  nsnps                    genealogy
# 0        0      0    1     1      1  (r6:3.33677e+06,((r3:737...
# 1        1      0    1     1      1  ((r3:1.02472e+06,r5:1.02...
# 2        2      0    1     1      1  (r0:4.08496e+06,((r7:2.4...
# 3        3      0    1     1      1  ((r2:1.05782e+06,r0:1.05...
# 4        4      0    1     1      1  ((r2:1.50159e+06,(r6:1.0...
# ..     ...    ...  ...   ...    ...                          ...
# 995    995      0    1     1      1  ((r6:941804,r3:941804):1...
# 996    996      0    1     1      1  ((r5:2.38812e+06,r7:2.38...
# 997    997      0    1     1      1  ((r7:1.21434e+06,(r5:1.0...
# 998    998      0    1     1      1  ((r7:2.05576e+06,(r0:1.2...
# 999    999      0    1     1      1  ((r0:1.63448e+06,(r5:1.1...
#
# [1000 rows x 6 columns]

# %%
model.seqs
# Out:
# array([[3, 1, 3, ..., 0, 3, 3],
#        [2, 1, 1, ..., 0, 2, 2],
#        [2, 1, 3, ..., 1, 2, 2],
#        ...,
#        [0, 3, 3, ..., 1, 3, 3],
#        [2, 1, 1, ..., 0, 2, 3],
#        [2, 1, 3, ..., 1, 3, 2]], dtype=uint8)

# %% [markdown]
# #### 3b) Simulate a bunch of loci

# %%
# simulate N loci of len L 
model.sim_loci(100, 3000)

# %%
# view the genealogies and stats in a table
model.df
# Out:
#       locus  start   end  nbps  nsnps                    genealogy
# 0         0      0    21    21      1  ((r7:1.56192e+06,(r3:1.1...
# 1         0     21   121   100     12  ((r7:1.56192e+06,(r3:1.1...
# 2         0    121   166    45      9  ((r7:1.56192e+06,(r3:1.1...
# 3         0    166   191    25      5  ((r7:1.56192e+06,(r3:1.1...
# 4         0    191   203    12      1  ((r7:1.56192e+06,(r3:1.1...
# ...     ...    ...   ...   ...    ...                          ...
# 3842     99   2727  2809    82     23  ((r3:2.18634e+06,(r0:945...
# 3843     99   2809  2885    76     17  ((r3:2.18634e+06,(r0:945...
# 3844     99   2885  2927    42     12  ((r3:2.18634e+06,(r0:945...
# 3845     99   2927  2971    44     12  ((r3:992058,(r0:945210,r...
# 3846     99   2971  3000    29      7  (((r5:1.14777e+06,r7:1.1...
#
# [3847 rows x 6 columns]

# %%
# view sequence data as an array
model.seqs
# Out:
# array([[[2, 1, 0, ..., 2, 2, 3],
#         [2, 1, 0, ..., 2, 1, 3],
#         [2, 1, 0, ..., 2, 1, 3],
#         ...,
#         [2, 1, 0, ..., 2, 2, 3],
#         [2, 1, 0, ..., 2, 1, 3],
#         [2, 1, 0, ..., 2, 1, 3]],
#
#        [[2, 3, 3, ..., 0, 1, 2],
#         [2, 3, 3, ..., 0, 1, 2],
#         [2, 3, 3, ..., 0, 1, 2],
#         ...,
#         [2, 3, 3, ..., 0, 1, 2],
#         [2, 3, 3, ..., 0, 1, 2],
#         [2, 3, 3, ..., 0, 1, 2]],
#
#        [[2, 1, 0, ..., 2, 3, 1],
#         [2, 1, 0, ..., 2, 3, 1],
#         [2, 1, 0, ..., 2, 0, 1],
#         ...,
#         [2, 1, 0, ..., 2, 0, 1],
#         [2, 1, 0, ..., 2, 3, 1],
#         [2, 1, 0, ..., 2, 0, 1]],
#
#        ...,
#
#        [[3, 0, 0, ..., 3, 2, 1],
#         [3, 0, 0, ..., 3, 2, 1],
#         [3, 0, 0, ..., 3, 2, 1],
#         ...,
#         [3, 0, 0, ..., 3, 2, 1],
#         [3, 0, 0, ..., 3, 2, 1],
#         [3, 0, 0, ..., 3, 2, 1]],
#
#        [[2, 2, 2, ..., 0, 1, 1],
#         [2, 2, 2, ..., 0, 1, 1],
#         [2, 2, 2, ..., 0, 1, 1],
#         ...,
#         [2, 2, 2, ..., 0, 1, 1],
#         [2, 2, 2, ..., 0, 1, 1],
#         [2, 2, 2, ..., 0, 1, 1]],
#
#        [[2, 1, 1, ..., 3, 2, 2],
#         [2, 1, 1, ..., 3, 2, 2],
#         [2, 1, 1, ..., 3, 2, 2],
#         ...,
#         [2, 1, 1, ..., 3, 2, 2],
#         [2, 1, 1, ..., 3, 2, 2],
#         [2, 1, 1, ..., 3, 2, 2]]], dtype=uint8)

# %% [markdown]
# #### 4) Infer a gene tree for each locus

# %%
# infer a tree for every locus
model.infer_gene_trees(inference_method='raxml')

# %%
# inferred_tree column is now added to the dataframe!
model.df
# Out:
#       locus  start   end  nbps  nsnps                    genealogy  \
# 0         0      0    21    21      1  ((r7:1.56192e+06,(r3:1.1...
# 1         0     21   121   100     12  ((r7:1.56192e+06,(r3:1.1...
# 2         0    121   166    45      9  ((r7:1.56192e+06,(r3:1.1...
# 3         0    166   191    25      5  ((r7:1.56192e+06,(r3:1.1...
# 4         0    191   203    12      1  ((r7:1.56192e+06,(r3:1.1...
# ...     ...    ...   ...   ...    ...                          ...
# 3842     99   2727  2809    82     23  ((r3:2.18634e+06,(r0:945...
# 3843     99   2809  2885    76     17  ((r3:2.18634e+06,(r0:945...
# 3844     99   2885  2927    42     12  ((r3:2.18634e+06,(r0:945...
# 3845     99   2927  2971    44     12  ((r3:992058,(r0:945210,r...
# 3846     99   2971  3000    29      7  (((r5:1.14777e+06,r7:1.1...
#
#                     inferred_tree
# 0     ((r4:0.02105516863155426...
# 1     ((r4:0.02105516863155426...
# 2     ((r4:0.02105516863155426...
# 3     ((r4:0.02105516863155426...
# 4     ((r4:0.02105516863155426...
# ...                           ...
# 3842  ((r3:0.01625070763953974...
# 3843  ((r3:0.01625070763953974...
# 3844  ((r3:0.01625070763953974...
# 3845  ((r3:0.01625070763953974...
# 3846  ((r3:0.01625070763953974...
#
# [3847 rows x 7 columns]
