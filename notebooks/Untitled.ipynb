# %%
import numpy as np
from numba import jit

# %%
270-125
# Out:
# 145

# %%
145**(1/3)
# Out:
# 5.253587872492901

# %%
5**3+6**3
# Out:
# 341

# %%
len("984509872305987203958709879223423549875")
# Out:
# 39

# %%
984509872305987203958709879223423549875*.1
# Out:
# 9.845098723059872e+37

# %%
(2984509872305987203958709879223423549875**3 - 984509872305987203958709879223423549875**3)**(1/3)
# Out:
# 2.948363608378046e+39

# %%
984509872305987203958709879223423549875**3+ 2.948363608378047e+39**3
# Out:
# 2.658392233200103e+118

# %%
# %%timeit
num_ = 1000000
holder = []#np.zeros((num_))
for i in range(num_):
    holder.append(i**3)# = (i**3)
# Out:
# 558 ms ± 7.43 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
num_ = 10000000
holder = []#np.zeros((num_))
for i in range(num_):
    holder.append(i**3)# = (i**3)
# Out:
# 5.53 s ± 401 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
num_ = 100000000
holder = []#np.zeros((num_))
for i in range(num_):
    holder.append(i**3)# = (i**3)
# Out:
# 59.4 s ± 5.97 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
1e8  # 1 min
1e9  # 10
1e10 # 100
1e11 # 1000
1e12 # 10000
1e13 # 1e5
1e14 # 1e6
1e15 # 1e7
1e16 # 1e8
1e17 # 1e9
1e18 # 1e10

# %%
holder
# Out:
# [0,
#  1,
#  8,
#  27,
#  64,
#  125,
#  216,
#  343,
#  512,
#  729,
#  1000,
#  1331,
#  1728,
#  2197,
#  2744,
#  3375,
#  4096,
#  4913,
#  5832,
#  6859,
#  8000,
#  9261,
#  10648,
#  12167,
#  13824,
#  15625,
#  17576,
#  19683,
#  21952,
#  24389,
#  27000,
#  29791,
#  32768,
#  35937,
#  39304,
#  42875,
#  46656,
#  50653,
#  54872,
#  59319,
#  64000,
#  68921,
#  74088,
#  79507,
#  85184,
#  91125,
#  97336,
#  103823,
#  110592,
#  117649,
#  125000,
#  132651,
#  140608,
#  148877,
#  157464,
#  166375,
#  175616,
#  185193,
#  195112,
#  205379,
#  216000,
#  226981,
#  238328,
#  250047,
#  262144,
#  274625,
#  287496,
#  300763,
#  314432,
#  328509,
#  343000,
#  357911,
#  373248,
#  389017,
#  405224,
#  421875,
#  438976,
#  456533,
#  474552,
#  493039,
#  512000,
#  531441,
#  551368,
#  571787,
#  592704,
#  614125,
#  636056,
#  658503,
#  681472,
#  704969,
#  729000,
#  753571,
#  778688,
#  804357,
#  830584,
#  857375,
#  884736,
#  912673,
# ...

# %%
# %%timeit
np.random.randint(18, size=3)
# Out:
# 5.38 µs ± 92.9 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
np.random.randint(low=2, high = 18, size=3)
# Out:
# 3.14 µs ± 75 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
"".join(map(np.random.randint(10, size=15),str))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-c8af389c41ba> in <module>
# ----> 1 "".join(map(np.random.randint(10, size=15),str))
#
# TypeError: 'type' object is not iterable

# %%
@jit
def return_random_length(numlength):
    return int("".join(map(str,np.random.randint(10, size=numlength))))

# %%
# %%timeit
return_random_length(15)
# Out:
# 28.1 µs ± 1.85 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def return_random_length(numlength):
    return int("".join(map(str,np.random.randint(10, size=numlength))))

# %%
np.array([return_random_length(single_length) for single_length in np.random.randint(low=2, high = 18, size=3)])**3
# Out:
# array([-5785270207466421568,  4543048778547515315,  8743825501528977144])

# %%
# %%timeit
return_random_length1(15)
# Out:
# 22.7 µs ± 322 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
lens = 
while x != 700:
    x =

# %%
int("29872398723598723598723698724698724697")
# Out:
# 26656939863818162059560055687443582124175708250573211436946281337839898068428351939913567938308515363027577756873

# %%
from random import getrandbits

# %%
getrandbits(5)
# Out:
# 2

# %%
from random import randrange

# %%
minfound = 1e20**3
x0 = 0
y0 = 0
z0 = 0
for i in range(100000):
    x=[randrange(0,1000),randrange(0,1000),randrange(0,1000)] # get three big random numbers 
    maximum = x.pop(np.argmax(x))
    if abs(x[0]**3 + x[1]**3 - maximum**3) == 42:
        minfound = abs(x[0]**3 + x[1]**3 - maximum**3)
        x0 = x[0]
        y0 = x[1]
        z0 = maximum
print(minfound)
print(len(str(minfound)))
print([x0,y0,z0])
# Out:
# 1e+60
# 5
# [0, 0, 0]

# %%
47**3-31**3-42**3
# Out:
# -56

# %%
(-47)**3 +(31)**3 + (42)**3
# Out:
# 56

# %%
abs(-100)
# Out:
# 100

# %%
-80538738812075974**3+ 80435758145817515**3 + 12602123297335631**3
# Out:
# 42

# %%
269**3-7**3
# Out:
# 19464766

# %%
x0
# Out:
# 6

# %%
minfound
# Out:
# 310570

# %%
len(str(minfound))
# Out:
# 53

# %%
idxs = np.array([0,1,2])
maximum = x.pop(np.argmax(x))

# %%
x[0]**3 + x[1]**3 - maximum
# Out:
# 3003385336649316737731179372489437434286252938131042633896745450108965
